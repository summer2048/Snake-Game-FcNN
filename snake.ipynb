# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from IPython.display import clear_output
import random
from torch import nn
import os
from collections import deque
import numpy as np
import time
import copy

# %%
def box_drawer(lowerleft, ax, is_head = False):
    ax.add_patch(Rectangle((0.1+lowerleft[0], 0.1+lowerleft[1]), 0.8, 0.8,color='gray' if is_head else 'blue'))

# %%
def food_drawer(lowerleft, ax):
    ax.add_patch(Rectangle((0.2+lowerleft[0], 0.2+lowerleft[1]), 0.6, 0.6,color='red'))

# %%
def drawer(snake,food):
    if (snake == None or len(snake) == 0):
        return
    # draw axis
    fig, ax = plt.subplots()
    fig.set_figheight(30)
    fig.set_figwidth(40)
    ax.set_ylim(0,30)
    ax.set_xlim(0,40)
    # draw food
    food_drawer(food,ax)
    # draw head + body
    box_drawer(snake[0],ax,True)
    for i in range(1,len(snake)):
        box_drawer(snake[i],ax)
    plt.show()

# %%
directions = (0,1,0,-1,0)
class game:
    def __init__(self,w=30,h=20):
        # width:w
        # height:h
        self.w = w
        self.h = h
        self.reset()
        
    def reset(self):
        # reset the game
        self.snake = [(20,15),(19,15),(18,15)]
        self.end = False
        self.direction = 1
        self.score = 0
        self.iteration = 0
        self.place_food()
        
    def place_food(self):
        # replace if position is occupied
        self.food = (random.randint(0,39),random.randint(0,29))
        while self.food in self.snake:
            self.food = (random.randint(0,39),random.randint(0,29))

    def change_dir(self,dir):
        # dir == 0 -> turn left
        # dir == 1 -> no change
        # dir == 2 -> turn right
        self.direction = (self.direction + dir - 1 + 4) % 4
        
    def play_step(self, dir):
        # itration ++
        self.iteration += 1
        # change dir
        self.change_dir(dir)
        
        # compute next position
        next = (directions[self.direction],directions[self.direction+1])
        next = tuple(map(lambda i, j: i + j, self.snake[0], next))
        
        reward = 0
        # if collide or a step is too long
        if self.is_collide(next) or self.iteration > 100*len(self.snake):
            reward = -10
            self.end = True
            return reward, self.end, self.score
        
        # otherwise, game continue
        self.snake.insert(0,next)
        if next != self.food: # not eat food move
            self.snake.pop()
        else: # eat food move
            self.score += 1
            reward = 10
            self.place_food()
        return reward, self.end, self.score
    
    def is_collide(self,next):
        if next[0] < 0 or next[0] >= 40 or next[1] < 0 or next[1] >= 30:
            return True
        return (next in self.snake) and (next != self.snake[-1])

# %%
class player:
    # always go forward
    def __init__(self):
        pass
    def get_action(self,game):
        return 1

# %%
class random_player(player):
    def __init__(self):
        pass
    def get_action(self,game):
        return random.randint(0,2)

# %%
class ai_player(player):
    def __init__(self, model):
        self.agent = Agent()
        self.agent.model = model
    def get_action(self, game):
        state = self.agent.get_state(game)
        state0 = torch.tensor(state,dtype=torch.float32)
        return torch.argmax(self.agent.model(state0))

# %%
def play(speed = 0, player = random_player(), gui = True, iter = 1):
    sum = 0
    for i in range(iter):
        newgame = game()
        while newgame.end == False:
            newgame.play_step(player.get_action(newgame))
            if gui:
                clear_output(wait=True)
                drawer(newgame.snake,newgame.food)
                if speed > 0:
                    time.sleep(0.1/speed)
        sum += newgame.score
    if iter == 1:
        print('Game over! You got score: {}!'.format(sum))
    return sum/iter

# %%
# play(speed=0)

# %%
class QNet(nn.Module):
    def __init__(self, state, hidden1, hidden2, output):
        super().__init__()
        self.linear1 = nn.Sequential(nn.Linear(state, hidden1), nn.ReLU())
        self.linear2 = nn.Sequential(nn.Linear(hidden1, hidden2), nn.ReLU())
        self.linear3 = nn.Linear(hidden2, output)
        self.idx = 0
        
    def forward(self, x):
        x = self.linear1(x)
        x = self.linear2(x)
        x = self.linear3(x)
        return x

# %%
class QTrainer:
    def __init__(self, model, lr, gamma):
        self.model = model
        self.lr = lr
        self.gamma = gamma
        self.optimizer = optim.Adam(model.parameters(), lr=self.lr)
        self.criterion = nn.MSELoss()
    
    def train_step(self, state, action, reward, next_state, done):
        
        state = torch.tensor(state, dtype=torch.float)
        next_state = torch.tensor(next_state, dtype=torch.float)
        reward = torch.tensor(reward, dtype=torch.float)
        action = torch.tensor(action, dtype=torch.long)
        # short memory
        if len(state.shape) == 1:
            state = torch.unsqueeze(state, 0)
            next_state = torch.unsqueeze(next_state, 0)
            action = torch.unsqueeze(action, 0)
            reward = torch.unsqueeze(reward, 0)
            done = (done, )
        
        pred = self.model(state)
        target = pred.clone()
        for idx in range(len(done)):
            Q_new = reward[idx]
            if not done[idx]:
                Q_new = reward[idx] + self.gamma * torch.max(self.model(next_state[idx]))

#             print(action)
            target[idx][action[idx]] = Q_new
        
        self.optimizer.zero_grad()
        loss = self.criterion(target,pred)
        loss.backward()

        self.optimizer.step()

# %%
MAX_MEMORY = 120000
BATCH_SIZE = 1000
LR = 0.001

# %%
class Agent:

    def __init__(self):
        self.n_games = 0
        self.epsilon = 0 # randomness
        self.gamma = 0.9 # discount rate
        self.memory = deque(maxlen=MAX_MEMORY)
        self.model = QNet(11,128,64,3)
        self.trainer = QTrainer(self.model, lr=LR, gamma=self.gamma)


    def get_state(self, game):
        head = game.snake[0]
        col_u = game.is_collide((head[0],head[1]+1))
        col_r = game.is_collide((head[0]+1,head[1]))
        col_d = game.is_collide((head[0],head[1]-1))
        col_l = game.is_collide((head[0]-1,head[1]))
        dir_u = game.direction == 0
        dir_r = game.direction == 1
        dir_d = game.direction == 2
        dir_l = game.direction == 3

        state = [
            # Danger straight
            (dir_u and col_u) or 
            (dir_r and col_r) or 
            (dir_d and col_d) or 
            (dir_l and col_l),

            # Danger right
            (dir_u and col_r) or 
            (dir_r and col_d) or 
            (dir_d and col_l) or 
            (dir_l and col_u),

            # Danger left
            (dir_u and col_l) or 
            (dir_l and col_d) or 
            (dir_d and col_r) or 
            (dir_r and col_u),

            
            # Move direction
            dir_u,
            dir_r,
            dir_d,
            dir_l,
            
            # Food location 
            game.food[0] < head[0],  # food left
            game.food[0] > head[0],  # food right
            game.food[1] < head[1],  # food up
            game.food[1] > head[1]  # food down
            ]

        return np.array(state, dtype=int)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done)) # popleft if MAX_MEMORY is reached

    def train_long_memory(self):
        if len(self.memory) > BATCH_SIZE:
            mini_sample = random.sample(self.memory, BATCH_SIZE) # list of tuples
        else:
            mini_sample = self.memory
        states, actions, rewards, next_states, dones = zip(*mini_sample)
        self.trainer.train_step(states, actions, rewards, next_states, dones)


    def train_short_memory(self, state, action, reward, next_state, done):
        self.trainer.train_step(state, action, reward, next_state, done)

    def get_action(self, state):
        # random moves: tradeoff exploration / exploitation
        self.epsilon = 60 - self.n_games
        if random.randint(0, 200) < self.epsilon:
            final_move = random.randint(0,2)
        else:
            state0 = torch.tensor(state, dtype=torch.float)
            prediction = self.model(state0)
#             print(prediction)
            final_move = torch.argmax(prediction).item()
        return final_move

# %%
best = 0
scores = np.array([0])
averages = np.array([[0,0]])
def train():
    record = 0
    agent = Agent()
    game0 = game()
    copy0 = copy.deepcopy(agent.model)
    global best
    global averages
    global scores
    global ave_scores
    best = copy0
    while True:
        # get old state
        state_old = agent.get_state(game0)

        # get move
        final_move = agent.get_action(state_old)

        # perform move and get new state
        reward, done, score = game0.play_step(final_move)
        state_new = agent.get_state(game0)

        # train short memory
        agent.train_short_memory(state_old, final_move, reward, state_new, done)

        # remember
        agent.remember(state_old, final_move, reward, state_new, done)

        # if game over:
        if done:
            scores = np.append(scores, [score], axis=0)
            # if score greater than record
            if score > record:
                # repeat 10 times and get average score
                ave = play(player=ai_player(model=agent.model),gui=False,iter=10)
                if ave > averages[-1][1]:
                    record = score
                    averages = np.append(averages, [[agent.n_games,ave]], axis=0)
                    # record model if average score is good
                    best = copy.deepcopy(agent.model)
            else:
                ave = '-'
            # train long memory
            game0.reset()
            agent.n_games += 1
            agent.train_long_memory()
            print('Game', agent.n_games, 'Score', score, 'Average', ave, 'Average Record', averages[-1][1])
            print('length =',len(agent.memory))
            if len(agent.memory) >= MAX_MEMORY:
                break

# %%
train()
# Out:
# Game 1 Score 0 Average - Average Record 0
# length = 92
# Game 2 Score 1 Average 0.0 Average Record 0
# length = 236
# Game 3 Score 0 Average - Average Record 0
# length = 271
# Game 4 Score 0 Average - Average Record 0
# length = 311
# Game 5 Score 0 Average - Average Record 0
# length = 384
# Game 6 Score 0 Average - Average Record 0
# length = 596
# Game 7 Score 0 Average - Average Record 0
# length = 698
# Game 8 Score 0 Average - Average Record 0
# length = 753
# Game 9 Score 0 Average - Average Record 0
# length = 829
# Game 10 Score 0 Average - Average Record 0
# length = 1004
# Game 11 Score 0 Average - Average Record 0
# length = 1026
# Game 12 Score 0 Average - Average Record 0
# length = 1192
# Game 13 Score 0 Average - Average Record 0
# length = 1244
# Game 14 Score 0 Average - Average Record 0
# length = 1338
# Game 15 Score 0 Average - Average Record 0
# length = 1358
# Game 16 Score 0 Average - Average Record 0
# length = 1465
# Game 17 Score 0 Average - Average Record 0
# length = 1766
# Game 18 Score 1 Average 0.0 Average Record 0
# length = 1871
# Game 19 Score 0 Average - Average Record 0
# length = 1984
# Game 20 Score 0 Average - Average Record 0
# length = 2150
# Game 21 Score 1 Average 0.0 Average Record 0
# length = 2349
# Game 22 Score 0 Average - Average Record 0
# length = 2382
# Game 23 Score 0 Average - Average Record 0
# length = 2568
# Game 24 Score 0 Average - Average Record 0
# length = 2869
# Game 25 Score 0 Average - Average Record 0
# length = 2942
# Game 26 Score 0 Average - Average Record 0
# length = 2983
# Game 27 Score 0 Average - Average Record 0
# length = 3284
# Game 28 Score 0 Average - Average Record 0
# length = 3351
# Game 29 Score 1 Average 0.0 Average Record 0
# length = 3752
# Game 30 Score 0 Average - Average Record 0
# length = 3804
# Game 31 Score 0 Average - Average Record 0
# length = 3860
# Game 32 Score 0 Average - Average Record 0
# length = 4002
# Game 33 Score 1 Average 0.0 Average Record 0
# length = 4242
# Game 34 Score 0 Average - Average Record 0
# length = 4373
# Game 35 Score 0 Average - Average Record 0
# length = 4674
# Game 36 Score 1 Average 0.9 Average Record 0.9
# length = 5075
# Game 37 Score 0 Average - Average Record 0.9
# length = 5103
# Game 38 Score 0 Average - Average Record 0.9
# length = 5126
# Game 39 Score 0 Average - Average Record 0.9
# length = 5146
# Game 40 Score 0 Average - Average Record 0.9
# length = 5220
# Game 41 Score 0 Average - Average Record 0.9
# length = 5512
# Game 42 Score 1 Average - Average Record 0.9
# length = 5558
# Game 43 Score 0 Average - Average Record 0.9
# length = 5717
# Game 44 Score 0 Average - Average Record 0.9
# length = 6018
# Game 45 Score 0 Average - Average Record 0.9
# length = 6134
# Game 46 Score 0 Average - Average Record 0.9
# length = 6245
# Game 47 Score 0 Average - Average Record 0.9
# length = 6413
# Game 48 Score 1 Average - Average Record 0.9
# length = 6751
# Game 49 Score 1 Average - Average Record 0.9
# length = 7152
# Game 50 Score 0 Average - Average Record 0.9
# length = 7226
# Game 51 Score 0 Average - Average Record 0.9
# length = 7505
# Game 52 Score 0 Average - Average Record 0.9
# length = 7806
# Game 53 Score 2 Average 1.1 Average Record 1.1
# length = 8307
# Game 54 Score 0 Average - Average Record 1.1
# length = 8608
# Game 55 Score 0 Average - Average Record 1.1
# length = 8909
# Game 56 Score 1 Average - Average Record 1.1
# length = 9310
# Game 57 Score 0 Average - Average Record 1.1
# length = 9611
# Game 58 Score 0 Average - Average Record 1.1
# length = 9912
# Game 59 Score 0 Average - Average Record 1.1
# length = 10213
# Game 60 Score 0 Average - Average Record 1.1
# length = 10514
# Game 61 Score 0 Average - Average Record 1.1
# length = 10815
# Game 62 Score 0 Average - Average Record 1.1
# length = 11116
# Game 63 Score 0 Average - Average Record 1.1
# length = 11417
# Game 64 Score 1 Average - Average Record 1.1
# length = 11818
# Game 65 Score 0 Average - Average Record 1.1
# length = 12119
# Game 66 Score 0 Average - Average Record 1.1
# length = 12420
# Game 67 Score 0 Average - Average Record 1.1
# length = 12721
# Game 68 Score 0 Average - Average Record 1.1
# length = 13022
# Game 69 Score 0 Average - Average Record 1.1
# length = 13323
# Game 70 Score 0 Average - Average Record 1.1
# length = 13624
# Game 71 Score 0 Average - Average Record 1.1
# length = 13925
# Game 72 Score 0 Average - Average Record 1.1
# length = 14226
# Game 73 Score 0 Average - Average Record 1.1
# length = 14527
# Game 74 Score 0 Average - Average Record 1.1
# length = 14828
# Game 75 Score 0 Average - Average Record 1.1
# length = 15129
# Game 76 Score 0 Average - Average Record 1.1
# length = 15430
# Game 77 Score 0 Average - Average Record 1.1
# length = 15731
# Game 78 Score 0 Average - Average Record 1.1
# length = 16032
# Game 79 Score 0 Average - Average Record 1.1
# length = 16333
# Game 80 Score 0 Average - Average Record 1.1
# length = 16634
# Game 81 Score 0 Average - Average Record 1.1
# length = 16935
# Game 82 Score 0 Average - Average Record 1.1
# length = 17236
# Game 83 Score 0 Average - Average Record 1.1
# length = 17537
# Game 84 Score 0 Average - Average Record 1.1
# length = 17838
# Game 85 Score 0 Average - Average Record 1.1
# length = 18139
# Game 86 Score 0 Average - Average Record 1.1
# length = 18440
# Game 87 Score 0 Average - Average Record 1.1
# length = 18741
# Game 88 Score 0 Average - Average Record 1.1
# length = 19042
# Game 89 Score 0 Average - Average Record 1.1
# length = 19343
# Game 90 Score 0 Average - Average Record 1.1
# length = 19644
# Game 91 Score 0 Average - Average Record 1.1
# length = 19945
# Game 92 Score 0 Average - Average Record 1.1
# length = 20246
# Game 93 Score 0 Average - Average Record 1.1
# length = 20547
# Game 94 Score 0 Average - Average Record 1.1
# length = 20848
# Game 95 Score 0 Average - Average Record 1.1
# length = 21149
# Game 96 Score 0 Average - Average Record 1.1
# length = 21450
# Game 97 Score 0 Average - Average Record 1.1
# length = 21751
# Game 98 Score 0 Average - Average Record 1.1
# length = 22052
# Game 99 Score 0 Average - Average Record 1.1
# length = 22353
# Game 100 Score 0 Average - Average Record 1.1
# length = 22654
# Game 101 Score 0 Average - Average Record 1.1
# length = 22955
# Game 102 Score 0 Average - Average Record 1.1
# length = 23256
# Game 103 Score 0 Average - Average Record 1.1
# length = 23557
# Game 104 Score 0 Average - Average Record 1.1
# length = 23858
# Game 105 Score 0 Average - Average Record 1.1
# length = 24159
# Game 106 Score 0 Average - Average Record 1.1
# length = 24460
# Game 107 Score 0 Average - Average Record 1.1
# length = 24761
# Game 108 Score 0 Average - Average Record 1.1
# length = 25062
# Game 109 Score 0 Average - Average Record 1.1
# length = 25363
# Game 110 Score 0 Average - Average Record 1.1
# length = 25664
# Game 111 Score 0 Average - Average Record 1.1
# length = 25965
# Game 112 Score 0 Average - Average Record 1.1
# length = 26266
# Game 113 Score 0 Average - Average Record 1.1
# length = 26567
# Game 114 Score 0 Average - Average Record 1.1
# length = 26868
# Game 115 Score 1 Average - Average Record 1.1
# length = 27269
# Game 116 Score 1 Average - Average Record 1.1
# length = 27670
# Game 117 Score 1 Average - Average Record 1.1
# length = 27714
# Game 118 Score 0 Average - Average Record 1.1
# length = 28015
# Game 119 Score 0 Average - Average Record 1.1
# length = 28316
# Game 120 Score 0 Average - Average Record 1.1
# length = 28617
# Game 121 Score 0 Average - Average Record 1.1
# length = 28918
# Game 122 Score 0 Average - Average Record 1.1
# length = 29219
# Game 123 Score 0 Average - Average Record 1.1
# length = 29520
# Game 124 Score 0 Average - Average Record 1.1
# length = 29821
# Game 125 Score 0 Average - Average Record 1.1
# length = 30122
# Game 126 Score 0 Average - Average Record 1.1
# length = 30423
# Game 127 Score 0 Average - Average Record 1.1
# length = 30724
# Game 128 Score 0 Average - Average Record 1.1
# length = 31025
# Game 129 Score 0 Average - Average Record 1.1
# length = 31326
# Game 130 Score 5 Average 0.7 Average Record 1.1
# length = 32127
# Game 131 Score 0 Average - Average Record 1.1
# length = 32428
# Game 132 Score 0 Average - Average Record 1.1
# length = 32729
# Game 133 Score 0 Average - Average Record 1.1
# length = 33030
# Game 134 Score 0 Average - Average Record 1.1
# length = 33132
# Game 135 Score 0 Average - Average Record 1.1
# length = 33234
# Game 136 Score 12 Average 1.8 Average Record 1.8
# length = 34735
# Game 137 Score 1 Average - Average Record 1.8
# length = 35136
# Game 138 Score 0 Average - Average Record 1.8
# length = 35437
# Game 139 Score 0 Average - Average Record 1.8
# length = 35738
# Game 140 Score 8 Average - Average Record 1.8
# length = 36464
# Game 141 Score 10 Average - Average Record 1.8
# length = 37348
# Game 142 Score 2 Average - Average Record 1.8
# length = 37450
# Game 143 Score 3 Average - Average Record 1.8
# length = 38004
# Game 144 Score 4 Average - Average Record 1.8
# length = 38705
# Game 145 Score 0 Average - Average Record 1.8
# length = 39006
# Game 146 Score 0 Average - Average Record 1.8
# length = 39307
# Game 147 Score 0 Average - Average Record 1.8
# length = 39608
# Game 148 Score 0 Average - Average Record 1.8
# length = 39909
# Game 149 Score 0 Average - Average Record 1.8
# length = 40210
# Game 150 Score 0 Average - Average Record 1.8
# length = 40511
# Game 151 Score 4 Average - Average Record 1.8
# length = 40680
# Game 152 Score 1 Average - Average Record 1.8
# length = 41081
# Game 153 Score 1 Average - Average Record 1.8
# length = 41482
# Game 154 Score 1 Average - Average Record 1.8
# length = 41883
# Game 155 Score 0 Average - Average Record 1.8
# length = 42184
# Game 156 Score 0 Average - Average Record 1.8
# length = 42485
# Game 157 Score 0 Average - Average Record 1.8
# length = 42786
# Game 158 Score 0 Average - Average Record 1.8
# length = 43087
# Game 159 Score 3 Average - Average Record 1.8
# length = 43688
# Game 160 Score 3 Average - Average Record 1.8
# length = 44289
# Game 161 Score 0 Average - Average Record 1.8
# length = 44590
# Game 162 Score 0 Average - Average Record 1.8
# length = 44891
# Game 163 Score 0 Average - Average Record 1.8
# length = 45192
# Game 164 Score 3 Average - Average Record 1.8
# length = 45793
# Game 165 Score 0 Average - Average Record 1.8
# length = 46094
# Game 166 Score 0 Average - Average Record 1.8
# length = 46395
# Game 167 Score 1 Average - Average Record 1.8
# length = 46796
# Game 168 Score 0 Average - Average Record 1.8
# length = 47097
# Game 169 Score 1 Average - Average Record 1.8
# length = 47498
# Game 170 Score 1 Average - Average Record 1.8
# length = 47899
# Game 171 Score 0 Average - Average Record 1.8
# length = 48200
# Game 172 Score 1 Average - Average Record 1.8
# length = 48601
# Game 173 Score 7 Average - Average Record 1.8
# length = 49602
# Game 174 Score 2 Average - Average Record 1.8
# length = 49687
# Game 175 Score 1 Average - Average Record 1.8
# length = 50088
# Game 176 Score 0 Average - Average Record 1.8
# length = 50389
# Game 177 Score 3 Average - Average Record 1.8
# length = 50644
# Game 178 Score 10 Average - Average Record 1.8
# length = 51022
# Game 179 Score 1 Average - Average Record 1.8
# length = 51423
# Game 180 Score 0 Average - Average Record 1.8
# length = 51724
# Game 181 Score 5 Average - Average Record 1.8
# length = 52525
# Game 182 Score 0 Average - Average Record 1.8
# length = 52826
# Game 183 Score 0 Average - Average Record 1.8
# length = 53127
# Game 184 Score 0 Average - Average Record 1.8
# length = 53428
# Game 185 Score 5 Average - Average Record 1.8
# length = 53647
# Game 186 Score 2 Average - Average Record 1.8
# length = 53699
# Game 187 Score 0 Average - Average Record 1.8
# length = 54000
# Game 188 Score 2 Average - Average Record 1.8
# length = 54501
# Game 189 Score 2 Average - Average Record 1.8
# length = 54593
# Game 190 Score 1 Average - Average Record 1.8
# length = 54994
# Game 191 Score 0 Average - Average Record 1.8
# length = 55295
# Game 192 Score 2 Average - Average Record 1.8
# length = 55358
# Game 193 Score 0 Average - Average Record 1.8
# length = 55418
# Game 194 Score 0 Average - Average Record 1.8
# length = 55719
# Game 195 Score 9 Average - Average Record 1.8
# length = 56920
# Game 196 Score 0 Average - Average Record 1.8
# length = 57221
# Game 197 Score 4 Average - Average Record 1.8
# length = 57359
# Game 198 Score 6 Average - Average Record 1.8
# length = 57628
# Game 199 Score 0 Average - Average Record 1.8
# length = 57712
# Game 200 Score 8 Average - Average Record 1.8
# length = 57902
# Game 201 Score 0 Average - Average Record 1.8
# length = 58203
# Game 202 Score 17 Average 16.3 Average Record 16.3
# length = 58774
# Game 203 Score 21 Average 21.4 Average Record 21.4
# length = 59252
# Game 204 Score 5 Average - Average Record 21.4
# length = 59396
# Game 205 Score 2 Average - Average Record 21.4
# length = 59507
# Game 206 Score 15 Average - Average Record 21.4
# length = 59932
# Game 207 Score 22 Average 3.4 Average Record 21.4
# length = 60443
# Game 208 Score 22 Average 18.2 Average Record 21.4
# length = 61125
# Game 209 Score 22 Average 21.2 Average Record 21.4
# length = 61761
# Game 210 Score 20 Average - Average Record 21.4
# length = 62240
# Game 211 Score 16 Average - Average Record 21.4
# length = 62635
# Game 212 Score 20 Average - Average Record 21.4
# length = 63177
# Game 213 Score 5 Average - Average Record 21.4
# length = 63444
# Game 214 Score 32 Average 18.5 Average Record 21.4
# length = 64332
# Game 215 Score 31 Average 33.0 Average Record 33.0
# length = 65153
# Game 216 Score 20 Average - Average Record 33.0
# length = 65570
# Game 217 Score 30 Average - Average Record 33.0
# length = 66388
# Game 218 Score 7 Average - Average Record 33.0
# length = 66588
# Game 219 Score 25 Average - Average Record 33.0
# length = 67408
# Game 220 Score 22 Average - Average Record 33.0
# length = 68050
# Game 221 Score 26 Average - Average Record 33.0
# length = 68695
# Game 222 Score 14 Average - Average Record 33.0
# length = 69004
# Game 223 Score 48 Average 32.7 Average Record 33.0
# length = 70290
# Game 224 Score 30 Average - Average Record 33.0
# length = 71041
# Game 225 Score 30 Average - Average Record 33.0
# length = 71830
# Game 226 Score 42 Average 43.9 Average Record 43.9
# length = 72890
# Game 227 Score 45 Average 37.3 Average Record 43.9
# length = 74139
# Game 228 Score 33 Average - Average Record 43.9
# length = 74919
# Game 229 Score 49 Average 9.5 Average Record 43.9
# length = 76181
# Game 230 Score 8 Average - Average Record 43.9
# length = 76349
# Game 231 Score 60 Average 27.3 Average Record 43.9
# length = 78051
# Game 232 Score 30 Average - Average Record 43.9
# length = 78897
# Game 233 Score 24 Average - Average Record 43.9
# length = 79588
# Game 234 Score 29 Average - Average Record 43.9
# length = 80641
# Game 235 Score 12 Average - Average Record 43.9
# length = 81075
# Game 236 Score 53 Average 39.6 Average Record 43.9
# length = 82421
# Game 237 Score 70 Average 40.7 Average Record 43.9
# length = 84966
# Game 238 Score 66 Average 40.9 Average Record 43.9
# length = 86373
# Game 239 Score 35 Average - Average Record 43.9
# length = 87129
# Game 240 Score 59 Average 32.4 Average Record 43.9
# length = 88636
# Game 241 Score 44 Average 35.1 Average Record 43.9
# length = 89768
# Game 242 Score 48 Average 36.6 Average Record 43.9
# length = 91109
# Game 243 Score 51 Average 38.5 Average Record 43.9
# length = 92531
# Game 244 Score 30 Average - Average Record 43.9
# length = 93327
# Game 245 Score 37 Average - Average Record 43.9
# length = 94302
# Game 246 Score 11 Average - Average Record 43.9
# length = 94546
# Game 247 Score 47 Average 31.8 Average Record 43.9
# length = 95745
# Game 248 Score 31 Average - Average Record 43.9
# length = 96590
# Game 249 Score 12 Average - Average Record 43.9
# length = 96916
# Game 250 Score 79 Average 43.3 Average Record 43.9
# length = 98823
# Game 251 Score 32 Average - Average Record 43.9
# length = 99393
# Game 252 Score 34 Average - Average Record 43.9
# length = 100248
# Game 253 Score 37 Average - Average Record 43.9
# length = 101344
# Game 254 Score 43 Average 42.1 Average Record 43.9
# length = 102511
# Game 255 Score 10 Average - Average Record 43.9
# length = 102776
# Game 256 Score 44 Average 40.3 Average Record 43.9
# length = 103998
# Game 257 Score 29 Average - Average Record 43.9
# length = 104609
# Game 258 Score 33 Average - Average Record 43.9
# length = 105482
# Game 259 Score 24 Average - Average Record 43.9
# length = 106045
# Game 260 Score 34 Average - Average Record 43.9
# length = 106967
# Game 261 Score 40 Average - Average Record 43.9
# length = 107932
# Game 262 Score 43 Average 41.4 Average Record 43.9
# length = 109100
# Game 263 Score 41 Average - Average Record 43.9
# length = 110085
# Game 264 Score 33 Average - Average Record 43.9
# length = 111007
# Game 265 Score 22 Average - Average Record 43.9
# length = 111581
# Game 266 Score 48 Average 33.4 Average Record 43.9
# length = 112802
# Game 267 Score 60 Average 42.0 Average Record 43.9
# length = 114262
# Game 268 Score 28 Average - Average Record 43.9
# length = 114966
# Game 269 Score 58 Average 41.9 Average Record 43.9
# length = 116503
# Game 270 Score 23 Average - Average Record 43.9
# length = 117177
# Game 271 Score 44 Average 34.3 Average Record 43.9
# length = 118232
# Game 272 Score 49 Average 59.4 Average Record 59.4
# length = 119543
# Game 273 Score 62 Average 44.4 Average Record 59.4
# length = 120000

# %%
play(player=ai_player(model=best),gui=False,iter=10)
# Out:
# 46.2

# %%
len(scores)
# Out:
# 274

# %%
averages1 = np.append(averages,[[len(scores),averages[-1][1]]],axis=0).T

# %%
plt.plot(list(range(0,scores.size)),scores,color='b',label='per_game')
plt.plot(averages1[0],averages1[1],c='r',label='max_average')
plt.xlabel('n_games')
plt.ylabel('score')
plt.title('AI player\'s scores with training game number increasing')
plt.show()

# %%
play(0,player=ai_player(best),gui=True)
# Out:
# Game over! You got score: 44!
# 44.0

# %%
random500 = [play(player=random_player(),gui=False) for i in range(500)]
# Out:
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 1!
# Game over! You got score: 1!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 2!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 2!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 3!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 2!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 2!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 1!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!
# Game over! You got score: 0!

# %%
plt.plot(list(range(500)),random500,color='b',label='per_game')
plt.xlabel('n_games')
plt.ylabel('score')
plt.title('Random Player\'s scores of 500 games')
plt.show()
